# %% [markdown]
# ## Model 6 finetune with ResNet50

# %%
import matplotlib

# import the necessary packages
#import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import ResNet50
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow import keras
from keras import optimizers
from tensorflow.keras import layers

from tensorflow.keras.utils import image_dataset_from_directory

# %%
DATASET_DIR  = r"F:\data for final project sem3\archive\Coronahack-Chest-XRay-Dataset\Coronahack-Chest-XRay-Dataset\exp4\train"

# %%
IMG_W = 150
IMG_H = 150
CHANNELS = 3

INPUT_SHAPE = (IMG_W, IMG_H, CHANNELS)
NB_CLASSES = 2
EPOCHS = 50
BATCH_SIZE = 8


train_datagen = ImageDataGenerator(rescale=1./255,
    #shear_range=0.2,
    #zoom_range=0.2,
    #horizontal_flip=True,
    validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    DATASET_DIR,
    target_size=(IMG_H, IMG_W),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    DATASET_DIR, 
    target_size=(IMG_H, IMG_W),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle= True,
    subset='validation')


new_base_dir = r"F:\data for final project sem3\archive\Coronahack-Chest-XRay-Dataset\Coronahack-Chest-XRay-Dataset\exp4\test"

train_datagen = ImageDataGenerator(rescale=1./255)

test_generator = train_datagen.flow_from_directory(new_base_dir,
                                                   target_size=(IMG_H, IMG_W),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='binary')
# Out:
# Found 480 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
conv_base = ResNet50(weights="imagenet",
                     include_top=False,
                     input_tensor=Input(shape=INPUT_SHAPE))

# %%
inputs = keras.Input(INPUT_SHAPE)
x = inputs
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model6 = keras.Model(inputs, outputs)
model6.compile(loss="binary_crossentropy",
optimizer="rmsprop",
metrics=["accuracy"])

# %%
conv_base.trainable = False

# %%
model6.compile(loss="binary_crossentropy",
               optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
               metrics=["accuracy",tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives()])
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning_resnet_model_try2_300.keras",
        save_best_only=True,
        monitor="val_loss")
]

history = model6.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 60/60 [==============================] - 32s 438ms/step - loss: 0.8323 - accuracy: 0.5104 - true_positives: 122.0000 - true_negatives: 123.0000 - val_loss: 0.6498 - val_accuracy: 0.5250 - val_true_positives: 3.0000 - val_true_negatives: 60.0000
# C:\Users\Dante\AppData\Roaming\Python\Python38\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/50
# 60/60 [==============================] - 10s 164ms/step - loss: 0.6965 - accuracy: 0.5729 - true_positives: 135.0000 - true_negatives: 140.0000 - val_loss: 0.5820 - val_accuracy: 0.7500 - val_true_positives: 48.0000 - val_true_negatives: 42.0000
# Epoch 3/50
# 60/60 [==============================] - 10s 167ms/step - loss: 0.6324 - accuracy: 0.6542 - true_positives: 156.0000 - true_negatives: 158.0000 - val_loss: 0.5522 - val_accuracy: 0.7833 - val_true_positives: 36.0000 - val_true_negatives: 58.0000
# Epoch 4/50
# 60/60 [==============================] - 10s 167ms/step - loss: 0.6008 - accuracy: 0.6938 - true_positives: 160.0000 - true_negatives: 173.0000 - val_loss: 0.6008 - val_accuracy: 0.5917 - val_true_positives: 55.0000 - val_true_negatives: 16.0000
# Epoch 5/50
# 60/60 [==============================] - 10s 160ms/step - loss: 0.5424 - accuracy: 0.7125 - true_positives: 175.0000 - true_negatives: 167.0000 - val_loss: 0.5187 - val_accuracy: 0.8250 - val_true_positives: 40.0000 - val_true_negatives: 59.0000
# Epoch 6/50
# 60/60 [==============================] - 10s 161ms/step - loss: 0.5387 - accuracy: 0.7583 - true_positives: 181.0000 - true_negatives: 183.0000 - val_loss: 0.4848 - val_accuracy: 0.8500 - val_true_positives: 46.0000 - val_true_negatives: 56.0000
# Epoch 7/50
# 60/60 [==============================] - 9s 158ms/step - loss: 0.4758 - accuracy: 0.7833 - true_positives: 185.0000 - true_negatives: 191.0000 - val_loss: 0.4930 - val_accuracy: 0.8333 - val_true_positives: 44.0000 - val_true_negatives: 56.0000
# Epoch 8/50
# 60/60 [==============================] - 10s 161ms/step - loss: 0.4551 - accuracy: 0.8042 - true_positives: 191.0000 - true_negatives: 195.0000 - val_loss: 0.4614 - val_accuracy: 0.8000 - val_true_positives: 48.0000 - val_true_negatives: 48.0000
# Epoch 9/50
# 60/60 [==============================] - 10s 159ms/step - loss: 0.4571 - accuracy: 0.8125 - true_positives: 192.0000 - true_negatives: 198.0000 - val_loss: 0.4473 - val_accuracy: 0.7833 - val_true_positives: 49.0000 - val_true_negatives: 45.0000
# Epoch 10/50
# 60/60 [==============================] - 9s 154ms/step - loss: 0.4264 - accuracy: 0.8188 - true_positives: 200.0000 - true_negatives: 193.0000 - val_loss: 0.4676 - val_accuracy: 0.8583 - val_true_positives: 48.0000 - val_true_negatives: 55.0000
# Epoch 11/50
# 60/60 [==============================] - 9s 156ms/step - loss: 0.4160 - accuracy: 0.8375 - true_positives: 197.0000 - true_negatives: 205.0000 - val_loss: 0.4337 - val_accuracy: 0.8667 - val_true_positives: 46.0000 - val_true_negatives: 58.0000
# Epoch 12/50
# 60/60 [==============================] - 9s 157ms/step - loss: 0.4169 - accuracy: 0.8229 - true_positives: 191.0000 - true_negatives: 204.0000 - val_loss: 0.4006 - val_accuracy: 0.8417 - val_true_positives: 48.0000 - val_true_negatives: 53.0000
# Epoch 13/50
# 60/60 [==============================] - 9s 154ms/step - loss: 0.4071 - accuracy: 0.8062 - true_positives: 195.0000 - true_negatives: 192.0000 - val_loss: 0.4386 - val_accuracy: 0.8333 - val_true_positives: 46.0000 - val_true_negatives: 54.0000
# Epoch 14/50
# 60/60 [==============================] - 9s 156ms/step - loss: 0.4026 - accuracy: 0.8375 - true_positives: 204.0000 - true_negatives: 198.0000 - val_loss: 0.4137 - val_accuracy: 0.8583 - val_true_positives: 46.0000 - val_true_negatives: 57.0000
# Epoch 15/50
# 60/60 [==============================] - 9s 156ms/step - loss: 0.3790 - accuracy: 0.8521 - true_positives: 198.0000 - true_negatives: 211.0000 - val_loss: 0.3970 - val_accuracy: 0.8167 - val_true_positives: 49.0000 - val_true_negatives: 49.0000
# Epoch 16/50
# 60/60 [==============================] - 10s 169ms/step - loss: 0.3896 - accuracy: 0.8354 - true_positives: 197.0000 - true_negatives: 204.0000 - val_loss: 0.4636 - val_accuracy: 0.8417 - val_true_positives: 42.0000 - val_true_negatives: 59.0000
# Epoch 17/50
# 60/60 [==============================] - 10s 160ms/step - loss: 0.3743 - accuracy: 0.8562 - true_positives: 200.0000 - true_negatives: 211.0000 - val_loss: 0.3991 - val_accuracy: 0.8167 - val_true_positives: 50.0000 - val_true_negatives: 48.0000
# Epoch 18/50
# 60/60 [==============================] - 10s 164ms/step - loss: 0.3667 - accuracy: 0.8562 - true_positives: 202.0000 - true_negatives: 209.0000 - val_loss: 0.3848 - val_accuracy: 0.8667 - val_true_positives: 48.0000 - val_true_negatives: 56.0000
# Epoch 19/50
# 60/60 [==============================] - 10s 165ms/step - loss: 0.3441 - accuracy: 0.8687 - true_positives: 203.0000 - true_negatives: 214.0000 - val_loss: 0.4104 - val_accuracy: 0.8667 - val_true_positives: 45.0000 - val_true_negatives: 59.0000
# Epoch 20/50
# 60/60 [==============================] - 10s 164ms/step - loss: 0.3392 - accuracy: 0.8646 - true_positives: 204.0000 - true_negatives: 211.0000 - val_loss: 0.3678 - val_accuracy: 0.8250 - val_true_positives: 50.0000 - val_true_negatives: 49.0000
# Epoch 21/50
# 60/60 [==============================] - 10s 159ms/step - loss: 0.3456 - accuracy: 0.8396 - true_positives: 201.0000 - true_negatives: 202.0000 - val_loss: 0.3744 - val_accuracy: 0.8500 - val_true_positives: 49.0000 - val_true_negatives: 53.0000
# Epoch 22/50
# 60/60 [==============================] - 10s 163ms/step - loss: 0.3421 - accuracy: 0.8729 - true_positives: 208.0000 - true_negatives: 211.0000 - val_loss: 0.3698 - val_accuracy: 0.8833 - val_true_positives: 49.0000 - val_true_negatives: 57.0000
# Epoch 23/50
# 60/60 [==============================] - 10s 164ms/step - loss: 0.3238 - accuracy: 0.8750 - true_positives: 208.0000 - true_negatives: 212.0000 - val_loss: 0.3684 - val_accuracy: 0.8583 - val_true_positives: 49.0000 - val_true_negatives: 54.0000
# Epoch 24/50
# 60/60 [==============================] - 10s 163ms/step - loss: 0.3386 - accuracy: 0.8667 - true_positives: 205.0000 - true_negatives: 211.0000 - val_loss: 0.3391 - val_accuracy: 0.8500 - val_true_positives: 51.0000 - val_true_negatives: 51.0000
# Epoch 25/50
# 60/60 [==============================] - 10s 160ms/step - loss: 0.3356 - accuracy: 0.8646 - true_positives: 206.0000 - true_negatives: 209.0000 - val_loss: 0.4504 - val_accuracy: 0.8417 - val_true_positives: 41.0000 - val_true_negatives: 60.0000
# Epoch 26/50
# 60/60 [==============================] - 10s 168ms/step - loss: 0.3136 - accuracy: 0.8938 - true_positives: 209.0000 - true_negatives: 220.0000 - val_loss: 0.3429 - val_accuracy: 0.8667 - val_true_positives: 48.0000 - val_true_negatives: 56.0000
# Epoch 27/50
# 60/60 [==============================] - 10s 164ms/step - loss: 0.3256 - accuracy: 0.8854 - true_positives: 206.0000 - true_negatives: 219.0000 - val_loss: 0.3349 - val_accuracy: 0.8833 - val_true_positives: 49.0000 - val_true_negatives: 57.0000
# Epoch 28/50
# 60/60 [==============================] - 10s 163ms/step - loss: 0.3262 - accuracy: 0.8646 - true_positives: 203.0000 - true_negatives: 212.0000 - val_loss: 0.3767 - val_accuracy: 0.8917 - val_true_positives: 47.0000 - val_true_negatives: 60.0000
# Epoch 29/50
# 60/60 [==============================] - 10s 160ms/step - loss: 0.3121 - accuracy: 0.8917 - true_positives: 207.0000 - true_negatives: 221.0000 - val_loss: 0.3043 - val_accuracy: 0.8583 - val_true_positives: 52.0000 - val_true_negatives: 51.0000
# Epoch 30/50
# 60/60 [==============================] - 10s 159ms/step - loss: 0.2998 - accuracy: 0.8896 - true_positives: 209.0000 - true_negatives: 218.0000 - val_loss: 0.3155 - val_accuracy: 0.8500 - val_true_positives: 53.0000 - val_true_negatives: 49.0000
# Epoch 31/50
# 60/60 [==============================] - 9s 159ms/step - loss: 0.3031 - accuracy: 0.8771 - true_positives: 207.0000 - true_negatives: 214.0000 - val_loss: 0.2984 - val_accuracy: 0.8917 - val_true_positives: 50.0000 - val_true_negatives: 57.0000
# Epoch 32/50
# 60/60 [==============================] - 10s 159ms/step - loss: 0.2941 - accuracy: 0.8896 - true_positives: 207.0000 - true_negatives: 220.0000 - val_loss: 0.3516 - val_accuracy: 0.9000 - val_true_positives: 49.0000 - val_true_negatives: 59.0000
# Epoch 33/50
# 60/60 [==============================] - 10s 160ms/step - loss: 0.2928 - accuracy: 0.8958 - true_positives: 209.0000 - true_negatives: 221.0000 - val_loss: 0.3667 - val_accuracy: 0.8583 - val_true_positives: 44.0000 - val_true_negatives: 59.0000ositive
# Epoch 34/50
# 60/60 [==============================] - 10s 161ms/step - loss: 0.2757 - accuracy: 0.8938 - true_positives: 206.0000 - true_negatives: 223.0000 - val_loss: 0.3396 - val_accuracy: 0.8667 - val_true_positives: 47.0000 - val_true_negatives: 57.0000
# Epoch 35/50
# 60/60 [==============================] - 10s 168ms/step - loss: 0.2908 - accuracy: 0.8958 - true_positives: 211.0000 - true_negatives: 219.0000 - val_loss: 0.3046 - val_accuracy: 0.8750 - val_true_positives: 50.0000 - val_true_negatives: 55.0000
# Epoch 36/50
# 60/60 [==============================] - 10s 172ms/step - loss: 0.2912 - accuracy: 0.8958 - true_positives: 212.0000 - true_negatives: 218.0000 - val_loss: 0.3021 - val_accuracy: 0.8917 - val_true_positives: 49.0000 - val_true_negatives: 58.0000
# Epoch 37/50
# 60/60 [==============================] - 10s 168ms/step - loss: 0.2859 - accuracy: 0.8917 - true_positives: 210.0000 - true_negatives: 218.0000 - val_loss: 0.2964 - val_accuracy: 0.8500 - val_true_positives: 53.0000 - val_true_negatives: 49.0000
# Epoch 38/50
# 60/60 [==============================] - 10s 165ms/step - loss: 0.2715 - accuracy: 0.9042 - true_positives: 213.0000 - true_negatives: 221.0000 - val_loss: 0.2643 - val_accuracy: 0.8667 - val_true_positives: 49.0000 - val_true_negatives: 55.0000
# Epoch 39/50
# 60/60 [==============================] - 10s 163ms/step - loss: 0.2748 - accuracy: 0.8958 - true_positives: 210.0000 - true_negatives: 220.0000 - val_loss: 0.3131 - val_accuracy: 0.8583 - val_true_positives: 55.0000 - val_true_negatives: 48.0000
# Epoch 40/50
# 60/60 [==============================] - 10s 167ms/step - loss: 0.2765 - accuracy: 0.8833 - true_positives: 213.0000 - true_negatives: 211.0000 - val_loss: 0.3285 - val_accuracy: 0.9000 - val_true_positives: 48.0000 - val_true_negatives: 60.0000
# Epoch 41/50
# 60/60 [==============================] - 10s 160ms/step - loss: 0.2725 - accuracy: 0.8875 - true_positives: 207.0000 - true_negatives: 219.0000 - val_loss: 0.2826 - val_accuracy: 0.8833 - val_true_positives: 53.0000 - val_true_negatives: 53.0000
# Epoch 42/50
# 60/60 [==============================] - 10s 161ms/step - loss: 0.2715 - accuracy: 0.8979 - true_positives: 208.0000 - true_negatives: 223.0000 - val_loss: 0.2966 - val_accuracy: 0.8833 - val_true_positives: 49.0000 - val_true_negatives: 57.0000
# Epoch 43/50
# 60/60 [==============================] - 10s 162ms/step - loss: 0.2534 - accuracy: 0.8979 - true_positives: 209.0000 - true_negatives: 222.0000 - val_loss: 0.2793 - val_accuracy: 0.8833 - val_true_positives: 54.0000 - val_true_negatives: 52.0000
# Epoch 44/50
# 60/60 [==============================] - 10s 161ms/step - loss: 0.2583 - accuracy: 0.9104 - true_positives: 218.0000 - true_negatives: 219.0000 - val_loss: 0.2608 - val_accuracy: 0.8917 - val_true_positives: 55.0000 - val_true_negatives: 52.0000
# Epoch 45/50
# 60/60 [==============================] - 10s 163ms/step - loss: 0.2763 - accuracy: 0.8958 - true_positives: 208.0000 - true_negatives: 222.0000 - val_loss: 0.2370 - val_accuracy: 0.8917 - val_true_positives: 50.0000 - val_true_negatives: 57.0000
# Epoch 46/50
# 60/60 [==============================] - 10s 163ms/step - loss: 0.2517 - accuracy: 0.8979 - true_positives: 212.0000 - true_negatives: 219.0000 - val_loss: 0.3134 - val_accuracy: 0.9083 - val_true_positives: 49.0000 - val_true_negatives: 60.0000
# Epoch 47/50
# 60/60 [==============================] - 10s 160ms/step - loss: 0.2563 - accuracy: 0.9125 - true_positives: 212.0000 - true_negatives: 226.0000 - val_loss: 0.2762 - val_accuracy: 0.9083 - val_true_positives: 50.0000 - val_true_negatives: 59.0000
# Epoch 48/50
# 60/60 [==============================] - 10s 160ms/step - loss: 0.2501 - accuracy: 0.9125 - true_positives: 216.0000 - true_negatives: 222.0000 - val_loss: 0.2813 - val_accuracy: 0.8917 - val_true_positives: 49.0000 - val_true_negatives: 58.0000
# Epoch 49/50
# 60/60 [==============================] - 9s 158ms/step - loss: 0.2394 - accuracy: 0.9167 - true_positives: 214.0000 - true_negatives: 226.0000 - val_loss: 0.2578 - val_accuracy: 0.8917 - val_true_positives: 55.0000 - val_true_negatives: 52.0000
# Epoch 50/50
# 60/60 [==============================] - 10s 157ms/step - loss: 0.2576 - accuracy: 0.9062 - true_positives: 213.0000 - true_negatives: 222.0000 - val_loss: 0.2754 - val_accuracy: 0.8917 - val_true_positives: 47.0000 - val_true_negatives: 60.0000

# %%
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
model6 = keras.models.load_model("fine_tuning_resnet_model_try2_300.keras")

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-3]:
    layer.trainable = False

# %%
model6.compile(loss="binary_crossentropy",
               optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
               metrics=["accuracy",tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives()])
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning_resnet_model_try2_300_2.keras",
        save_best_only=True,
        monitor="val_loss")
]

history = model6.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 60/60 [==============================] - 15s 185ms/step - loss: 0.2574 - accuracy: 0.8958 - true_positives_1: 211.0000 - true_negatives_1: 219.0000 - val_loss: 0.2464 - val_accuracy: 0.9167 - val_true_positives_1: 53.0000 - val_true_negatives_1: 57.0000
# Epoch 2/50
# 60/60 [==============================] - 9s 158ms/step - loss: 0.2490 - accuracy: 0.9187 - true_positives_1: 215.0000 - true_negatives_1: 226.0000 - val_loss: 0.3097 - val_accuracy: 0.9000 - val_true_positives_1: 48.0000 - val_true_negatives_1: 60.0000
# Epoch 3/50
# 60/60 [==============================] - 9s 157ms/step - loss: 0.2643 - accuracy: 0.9042 - true_positives_1: 215.0000 - true_negatives_1: 219.0000 - val_loss: 0.3342 - val_accuracy: 0.8833 - val_true_positives_1: 46.0000 - val_true_negatives_1: 60.0000
# Epoch 4/50
# 60/60 [==============================] - 10s 173ms/step - loss: 0.2492 - accuracy: 0.9083 - true_positives_1: 214.0000 - true_negatives_1: 222.0000 - val_loss: 0.2710 - val_accuracy: 0.8833 - val_true_positives_1: 50.0000 - val_true_negatives_1: 56.0000
# Epoch 5/50
# 60/60 [==============================] - 10s 173ms/step - loss: 0.2370 - accuracy: 0.9208 - true_positives_1: 217.0000 - true_negatives_1: 225.0000 - val_loss: 0.2433 - val_accuracy: 0.9000 - val_true_positives_1: 50.0000 - val_true_negatives_1: 58.0000
# Epoch 6/50
# 60/60 [==============================] - 9s 157ms/step - loss: 0.2471 - accuracy: 0.9125 - true_positives_1: 217.0000 - true_negatives_1: 221.0000 - val_loss: 0.2445 - val_accuracy: 0.9083 - val_true_positives_1: 51.0000 - val_true_negatives_1: 58.0000
# Epoch 7/50
# 60/60 [==============================] - 9s 157ms/step - loss: 0.2383 - accuracy: 0.9167 - true_positives_1: 218.0000 - true_negatives_1: 222.0000 - val_loss: 0.2687 - val_accuracy: 0.9000 - val_true_positives_1: 51.0000 - val_true_negatives_1: 57.0000
# Epoch 8/50
# 60/60 [==============================] - 10s 162ms/step - loss: 0.2356 - accuracy: 0.9125 - true_positives_1: 216.0000 - true_negatives_1: 222.0000 - val_loss: 0.2516 - val_accuracy: 0.9000 - val_true_positives_1: 49.0000 - val_true_negatives_1: 59.0000
# Epoch 9/50
# 60/60 [==============================] - 9s 155ms/step - loss: 0.2406 - accuracy: 0.9146 - true_positives_1: 215.0000 - true_negatives_1: 224.0000 - val_loss: 0.2487 - val_accuracy: 0.8833 - val_true_positives_1: 52.0000 - val_true_negatives_1: 54.0000
# Epoch 10/50
# 60/60 [==============================] - 10s 160ms/step - loss: 0.2382 - accuracy: 0.9146 - true_positives_1: 215.0000 - true_negatives_1: 224.0000 - val_loss: 0.2277 - val_accuracy: 0.9083 - val_true_positives_1: 53.0000 - val_true_negatives_1: 56.0000
# Epoch 11/50
# 60/60 [==============================] - 10s 165ms/step - loss: 0.2517 - accuracy: 0.9125 - true_positives_1: 212.0000 - true_negatives_1: 226.0000 - val_loss: 0.2250 - val_accuracy: 0.9000 - val_true_positives_1: 53.0000 - val_true_negatives_1: 55.0000
# Epoch 12/50
# 60/60 [==============================] - 10s 158ms/step - loss: 0.2357 - accuracy: 0.9187 - true_positives_1: 215.0000 - true_negatives_1: 226.0000 - val_loss: 0.2323 - val_accuracy: 0.8917 - val_true_positives_1: 54.0000 - val_true_negatives_1: 53.0000
# Epoch 13/50
# 60/60 [==============================] - 10s 159ms/step - loss: 0.2344 - accuracy: 0.9292 - true_positives_1: 220.0000 - true_negatives_1: 226.0000 - val_loss: 0.2555 - val_accuracy: 0.8917 - val_true_positives_1: 50.0000 - val_true_negatives_1: 57.0000
# Epoch 14/50
# 60/60 [==============================] - 10s 159ms/step - loss: 0.2484 - accuracy: 0.9083 - true_positives_1: 213.0000 - true_negatives_1: 223.0000 - val_loss: 0.2486 - val_accuracy: 0.9000 - val_true_positives_1: 50.0000 - val_true_negatives_1: 58.0000
# Epoch 15/50
# 60/60 [==============================] - 10s 161ms/step - loss: 0.2354 - accuracy: 0.9000 - true_positives_1: 212.0000 - true_negatives_1: 220.0000 - val_loss: 0.2140 - val_accuracy: 0.9000 - val_true_positives_1: 52.0000 - val_true_negatives_1: 56.0000
# Epoch 16/50
# 60/60 [==============================] - 10s 160ms/step - loss: 0.2233 - accuracy: 0.9146 - true_positives_1: 216.0000 - true_negatives_1: 223.0000 - val_loss: 0.2600 - val_accuracy: 0.9083 - val_true_positives_1: 50.0000 - val_true_negatives_1: 59.0000
# Epoch 17/50
# 60/60 [==============================] - 9s 155ms/step - loss: 0.2269 - accuracy: 0.9312 - true_positives_1: 220.0000 - true_negatives_1: 227.0000 - val_loss: 0.2364 - val_accuracy: 0.9167 - val_true_positives_1: 51.0000 - val_true_negatives_1: 59.0000
# Epoch 18/50
# 60/60 [==============================] - 9s 156ms/step - loss: 0.2339 - accuracy: 0.9229 - true_positives_1: 215.0000 - true_negatives_1: 228.0000 - val_loss: 0.2562 - val_accuracy: 0.8917 - val_true_positives_1: 48.0000 - val_true_negatives_1: 59.0000
# Epoch 19/50
# 60/60 [==============================] - 9s 155ms/step - loss: 0.2166 - accuracy: 0.9208 - true_positives_1: 218.0000 - true_negatives_1: 224.0000 - val_loss: 0.2528 - val_accuracy: 0.8917 - val_true_positives_1: 49.0000 - val_true_negatives_1: 58.0000
# Epoch 20/50
# 60/60 [==============================] - 9s 154ms/step - loss: 0.2339 - accuracy: 0.9167 - true_positives_1: 216.0000 - true_negatives_1: 224.0000 - val_loss: 0.2677 - val_accuracy: 0.8833 - val_true_positives_1: 49.0000 - val_true_negatives_1: 57.0000
# Epoch 21/50
# 60/60 [==============================] - 9s 155ms/step - loss: 0.2138 - accuracy: 0.9271 - true_positives_1: 220.0000 - true_negatives_1: 225.0000 - val_loss: 0.2114 - val_accuracy: 0.9000 - val_true_positives_1: 53.0000 - val_true_negatives_1: 55.0000
# Epoch 22/50
# 60/60 [==============================] - 9s 152ms/step - loss: 0.2170 - accuracy: 0.9271 - true_positives_1: 219.0000 - true_negatives_1: 226.0000 - val_loss: 0.2298 - val_accuracy: 0.9000 - val_true_positives_1: 53.0000 - val_true_negatives_1: 55.0000
# Epoch 23/50
# 60/60 [==============================] - 9s 159ms/step - loss: 0.2125 - accuracy: 0.9229 - true_positives_1: 219.0000 - true_negatives_1: 224.0000 - val_loss: 0.2127 - val_accuracy: 0.9250 - val_true_positives_1: 53.0000 - val_true_negatives_1: 58.0000
# Epoch 24/50
# 60/60 [==============================] - 9s 155ms/step - loss: 0.2141 - accuracy: 0.9229 - true_positives_1: 218.0000 - true_negatives_1: 225.0000 - val_loss: 0.2066 - val_accuracy: 0.9250 - val_true_positives_1: 54.0000 - val_true_negatives_1: 57.0000
# Epoch 25/50
# 60/60 [==============================] - 10s 160ms/step - loss: 0.2229 - accuracy: 0.9250 - true_positives_1: 219.0000 - true_negatives_1: 225.0000 - val_loss: 0.1971 - val_accuracy: 0.9250 - val_true_positives_1: 54.0000 - val_true_negatives_1: 57.0000
# Epoch 26/50
# 60/60 [==============================] - 9s 154ms/step - loss: 0.1952 - accuracy: 0.9229 - true_positives_1: 220.0000 - true_negatives_1: 223.0000 - val_loss: 0.1987 - val_accuracy: 0.9417 - val_true_positives_1: 54.0000 - val_true_negatives_1: 59.0000
# Epoch 27/50
# 60/60 [==============================] - 9s 155ms/step - loss: 0.2184 - accuracy: 0.9208 - true_positives_1: 215.0000 - true_negatives_1: 227.0000 - val_loss: 0.2370 - val_accuracy: 0.8917 - val_true_positives_1: 56.0000 - val_true_negatives_1: 51.0000
# Epoch 28/50
# 60/60 [==============================] - 9s 151ms/step - loss: 0.2084 - accuracy: 0.9354 - true_positives_1: 222.0000 - true_negatives_1: 227.0000 - val_loss: 0.2009 - val_accuracy: 0.9083 - val_true_positives_1: 55.0000 - val_true_negatives_1: 54.0000
# Epoch 29/50
# 60/60 [==============================] - 9s 154ms/step - loss: 0.2217 - accuracy: 0.9250 - true_positives_1: 219.0000 - true_negatives_1: 225.0000 - val_loss: 0.2925 - val_accuracy: 0.8917 - val_true_positives_1: 47.0000 - val_true_negatives_1: 60.0000
# Epoch 30/50
# 60/60 [==============================] - 9s 155ms/step - loss: 0.2187 - accuracy: 0.9250 - true_positives_1: 219.0000 - true_negatives_1: 225.0000 - val_loss: 0.2317 - val_accuracy: 0.9167 - val_true_positives_1: 51.0000 - val_true_negatives_1: 59.0000
# Epoch 31/50
# 60/60 [==============================] - 9s 152ms/step - loss: 0.2093 - accuracy: 0.9229 - true_positives_1: 218.0000 - true_negatives_1: 225.0000 - val_loss: 0.2112 - val_accuracy: 0.8917 - val_true_positives_1: 50.0000 - val_true_negatives_1: 57.0000
# Epoch 32/50
# 60/60 [==============================] - 9s 155ms/step - loss: 0.2140 - accuracy: 0.9125 - true_positives_1: 215.0000 - true_negatives_1: 223.0000 - val_loss: 0.2123 - val_accuracy: 0.9083 - val_true_positives_1: 54.0000 - val_true_negatives_1: 55.0000
# Epoch 33/50
# 60/60 [==============================] - 9s 150ms/step - loss: 0.2110 - accuracy: 0.9271 - true_positives_1: 219.0000 - true_negatives_1: 226.0000 - val_loss: 0.2195 - val_accuracy: 0.8917 - val_true_positives_1: 49.0000 - val_true_negatives_1: 58.0000
# Epoch 34/50
# 60/60 [==============================] - 9s 151ms/step - loss: 0.2031 - accuracy: 0.9354 - true_positives_1: 222.0000 - true_negatives_1: 227.0000 - val_loss: 0.2508 - val_accuracy: 0.8917 - val_true_positives_1: 49.0000 - val_true_negatives_1: 58.0000
# Epoch 35/50
# 60/60 [==============================] - 9s 151ms/step - loss: 0.1919 - accuracy: 0.9333 - true_positives_1: 221.0000 - true_negatives_1: 227.0000 - val_loss: 0.1887 - val_accuracy: 0.9250 - val_true_positives_1: 53.0000 - val_true_negatives_1: 58.0000
# Epoch 36/50
# 60/60 [==============================] - 9s 151ms/step - loss: 0.2018 - accuracy: 0.9396 - true_positives_1: 222.0000 - true_negatives_1: 229.0000 - val_loss: 0.2217 - val_accuracy: 0.9000 - val_true_positives_1: 50.0000 - val_true_negatives_1: 58.0000
# Epoch 37/50
# 60/60 [==============================] - 9s 149ms/step - loss: 0.1861 - accuracy: 0.9312 - true_positives_1: 222.0000 - true_negatives_1: 225.0000 - val_loss: 0.1935 - val_accuracy: 0.9250 - val_true_positives_1: 53.0000 - val_true_negatives_1: 58.0000
# Epoch 38/50
# 60/60 [==============================] - 9s 154ms/step - loss: 0.1829 - accuracy: 0.9375 - true_positives_1: 220.0000 - true_negatives_1: 230.0000 - val_loss: 0.2127 - val_accuracy: 0.9167 - val_true_positives_1: 52.0000 - val_true_negatives_1: 58.0000
# Epoch 39/50
# 60/60 [==============================] - 9s 150ms/step - loss: 0.1906 - accuracy: 0.9250 - true_positives_1: 216.0000 - true_negatives_1: 228.0000 - val_loss: 0.1819 - val_accuracy: 0.9167 - val_true_positives_1: 53.0000 - val_true_negatives_1: 57.0000
# Epoch 40/50
# 60/60 [==============================] - 9s 150ms/step - loss: 0.1816 - accuracy: 0.9229 - true_positives_1: 218.0000 - true_negatives_1: 225.0000 - val_loss: 0.2241 - val_accuracy: 0.9250 - val_true_positives_1: 52.0000 - val_true_negatives_1: 59.0000
# Epoch 41/50
# 60/60 [==============================] - 9s 149ms/step - loss: 0.1931 - accuracy: 0.9208 - true_positives_1: 219.0000 - true_negatives_1: 223.0000 - val_loss: 0.2536 - val_accuracy: 0.9000 - val_true_positives_1: 48.0000 - val_true_negatives_1: 60.0000
# Epoch 42/50
# 60/60 [==============================] - 9s 151ms/step - loss: 0.1859 - accuracy: 0.9417 - true_positives_1: 224.0000 - true_negatives_1: 228.0000 - val_loss: 0.1888 - val_accuracy: 0.9083 - val_true_positives_1: 54.0000 - val_true_negatives_1: 55.0000
# Epoch 43/50
# 60/60 [==============================] - 9s 149ms/step - loss: 0.1890 - accuracy: 0.9250 - true_positives_1: 216.0000 - true_negatives_1: 228.0000 - val_loss: 0.2117 - val_accuracy: 0.9250 - val_true_positives_1: 52.0000 - val_true_negatives_1: 59.0000
# Epoch 44/50
# 60/60 [==============================] - 9s 153ms/step - loss: 0.1924 - accuracy: 0.9271 - true_positives_1: 218.0000 - true_negatives_1: 227.0000 - val_loss: 0.2029 - val_accuracy: 0.9083 - val_true_positives_1: 52.0000 - val_true_negatives_1: 57.0000
# Epoch 45/50
# 60/60 [==============================] - 9s 151ms/step - loss: 0.1845 - accuracy: 0.9229 - true_positives_1: 218.0000 - true_negatives_1: 225.0000 - val_loss: 0.2024 - val_accuracy: 0.9083 - val_true_positives_1: 51.0000 - val_true_negatives_1: 58.0000
# Epoch 46/50
# 60/60 [==============================] - 9s 150ms/step - loss: 0.1952 - accuracy: 0.9333 - true_positives_1: 222.0000 - true_negatives_1: 226.0000 - val_loss: 0.1998 - val_accuracy: 0.9167 - val_true_positives_1: 50.0000 - val_true_negatives_1: 60.0000
# Epoch 47/50
# 60/60 [==============================] - 9s 152ms/step - loss: 0.2026 - accuracy: 0.9292 - true_positives_1: 220.0000 - true_negatives_1: 226.0000 - val_loss: 0.1664 - val_accuracy: 0.9167 - val_true_positives_1: 54.0000 - val_true_negatives_1: 56.0000
# Epoch 48/50
# 60/60 [==============================] - 9s 151ms/step - loss: 0.1896 - accuracy: 0.9250 - true_positives_1: 217.0000 - true_negatives_1: 227.0000 - val_loss: 0.1558 - val_accuracy: 0.9333 - val_true_positives_1: 53.0000 - val_true_negatives_1: 59.0000
# Epoch 49/50
# 60/60 [==============================] - 9s 149ms/step - loss: 0.1964 - accuracy: 0.9375 - true_positives_1: 222.0000 - true_negatives_1: 228.0000 - val_loss: 0.2062 - val_accuracy: 0.9000 - val_true_positives_1: 52.0000 - val_true_negatives_1: 56.0000
# Epoch 50/50
# 60/60 [==============================] - 9s 152ms/step - loss: 0.1916 - accuracy: 0.9250 - true_positives_1: 220.0000 - true_negatives_1: 224.0000 - val_loss: 0.1752 - val_accuracy: 0.9333 - val_true_positives_1: 53.0000 - val_true_negatives_1: 59.0000

# %%
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_loss, test_acc, true_pos, true_neg = model6.evaluate(test_generator)

print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 78/78 [==============================] - 6s 75ms/step - loss: 0.3553 - accuracy: 0.8365 - true_positives_1: 369.0000 - true_negatives_1: 153.0000
# Test accuracy: 0.837
