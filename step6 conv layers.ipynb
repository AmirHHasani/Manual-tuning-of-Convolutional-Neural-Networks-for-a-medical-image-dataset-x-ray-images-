# %%
import tensorflow as tf
from tensorflow import keras
from keras import optimizers

from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense, AvgPool2D,MaxPool2D
from keras.models import Sequential, Model

from tensorflow.keras.optimizers import Adam, SGD, RMSprop

from tensorflow.keras import layers
from tensorflow.keras import regularizers

import matplotlib.pyplot as plt

from tensorflow.keras.utils import image_dataset_from_directory

import numpy as np

# %%
IMG_W = 150
IMG_H = 150
CHANNELS = 3

INPUT_SHAPE = (IMG_W, IMG_H, CHANNELS)
NB_CLASSES = 2
EPOCHS = 20
BATCH_SIZE = 16

# %%
new_base_dir = "./2-step/split data"

#new_base_dir = pathlib.Path("./2-step/split data")

# %%
train_dataset = image_dataset_from_directory(
new_base_dir + "/train",
image_size=(IMG_W, IMG_W),
batch_size=BATCH_SIZE
)

validation_dataset = image_dataset_from_directory(
new_base_dir + "/val",
image_size=(IMG_W, IMG_W),
batch_size=BATCH_SIZE,
)

test_dataset = image_dataset_from_directory(
new_base_dir + "/test",
image_size=(IMG_W, IMG_W),
batch_size=BATCH_SIZE
)
# Out:
# Found 2100 files belonging to 2 classes.
# Found 450 files belonging to 2 classes.
# Found 450 files belonging to 2 classes.

# %%
# adding a conv(64)

# %%
inputs = keras.Input(shape=INPUT_SHAPE)
#-----------------------------------------------------------------
x = inputs
x = layers.Rescaling(1./255)(inputs)
#---------------------------------------------------------------------------------------
x = layers.Conv2D(filters=8, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=16, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)

x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)


x = layers.Flatten()(x)
x = layers.Dense(8, activation="sigmoid")(x)

#kernel_regularizer=regularizers.l2(0.002)
#x = layers.Dropout(0.25)(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
               optimizer="rmsprop",
               metrics=["accuracy",tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives()])


history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = EPOCHS)
# Out:
# Epoch 1/20
# 132/132 [==============================] - 7s 43ms/step - loss: 0.4980 - accuracy: 0.7448 - true_positives_1: 737.0000 - true_negatives_1: 827.0000 - val_loss: 0.3391 - val_accuracy: 0.8800 - val_true_positives_1: 177.0000 - val_true_negatives_1: 219.0000
# Epoch 2/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.3403 - accuracy: 0.8710 - true_positives_1: 914.0000 - true_negatives_1: 915.0000 - val_loss: 0.3286 - val_accuracy: 0.8733 - val_true_positives_1: 171.0000 - val_true_negatives_1: 222.0000
# Epoch 3/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.2956 - accuracy: 0.8886 - true_positives_1: 932.0000 - true_negatives_1: 934.0000 - val_loss: 0.4064 - val_accuracy: 0.8400 - val_true_positives_1: 218.0000 - val_true_negatives_1: 160.0000
# Epoch 4/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.2733 - accuracy: 0.9024 - true_positives_1: 951.0000 - true_negatives_1: 944.0000 - val_loss: 0.2782 - val_accuracy: 0.9022 - val_true_positives_1: 211.0000 - val_true_negatives_1: 195.0000
# Epoch 5/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.2387 - accuracy: 0.9186 - true_positives_1: 960.0000 - true_negatives_1: 969.0000 - val_loss: 0.2396 - val_accuracy: 0.9044 - val_true_positives_1: 202.0000 - val_true_negatives_1: 205.0000
# Epoch 6/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.2187 - accuracy: 0.9219 - true_positives_1: 970.0000 - true_negatives_1: 966.0000 - val_loss: 0.2271 - val_accuracy: 0.9200 - val_true_positives_1: 204.0000 - val_true_negatives_1: 210.0000
# Epoch 7/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.2144 - accuracy: 0.9229 - true_positives_1: 971.0000 - true_negatives_1: 967.0000 - val_loss: 0.2286 - val_accuracy: 0.9200 - val_true_positives_1: 199.0000 - val_true_negatives_1: 215.0000
# Epoch 8/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1893 - accuracy: 0.9381 - true_positives_1: 988.0000 - true_negatives_1: 982.0000 - val_loss: 0.2348 - val_accuracy: 0.9156 - val_true_positives_1: 193.0000 - val_true_negatives_1: 219.0000
# Epoch 9/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1873 - accuracy: 0.9295 - true_positives_1: 974.0000 - true_negatives_1: 978.0000 - val_loss: 0.2207 - val_accuracy: 0.9267 - val_true_positives_1: 202.0000 - val_true_negatives_1: 215.0000
# Epoch 10/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.1698 - accuracy: 0.9429 - true_positives_1: 989.0000 - true_negatives_1: 991.0000 - val_loss: 0.3810 - val_accuracy: 0.8622 - val_true_positives_1: 166.0000 - val_true_negatives_1: 222.0000
# Epoch 11/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.1561 - accuracy: 0.9476 - true_positives_1: 989.0000 - true_negatives_1: 1001.0000 - val_loss: 0.2038 - val_accuracy: 0.9244 - val_true_positives_1: 201.0000 - val_true_negatives_1: 215.0000
# Epoch 12/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1536 - accuracy: 0.9524 - true_positives_1: 999.0000 - true_negatives_1: 1001.0000 - val_loss: 0.2098 - val_accuracy: 0.9178 - val_true_positives_1: 194.0000 - val_true_negatives_1: 219.0000
# Epoch 13/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.1354 - accuracy: 0.9505 - true_positives_1: 997.0000 - true_negatives_1: 999.0000 - val_loss: 0.1981 - val_accuracy: 0.9378 - val_true_positives_1: 205.0000 - val_true_negatives_1: 217.0000
# Epoch 14/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.1229 - accuracy: 0.9652 - true_positives_1: 1011.0000 - true_negatives_1: 1016.0000 - val_loss: 0.2133 - val_accuracy: 0.9222 - val_true_positives_1: 206.0000 - val_true_negatives_1: 209.0000
# Epoch 15/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.1188 - accuracy: 0.9619 - true_positives_1: 1013.0000 - true_negatives_1: 1007.0000 - val_loss: 0.2775 - val_accuracy: 0.9000 - val_true_positives_1: 187.0000 - val_true_negatives_1: 218.0000
# Epoch 16/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.1121 - accuracy: 0.9657 - true_positives_1: 1011.0000 - true_negatives_1: 1017.0000 - val_loss: 0.2083 - val_accuracy: 0.9311 - val_true_positives_1: 203.0000 - val_true_negatives_1: 216.0000
# Epoch 17/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1100 - accuracy: 0.9676 - true_positives_1: 1019.0000 - true_negatives_1: 1013.0000 - val_loss: 0.2262 - val_accuracy: 0.9267 - val_true_positives_1: 203.0000 - val_true_negatives_1: 214.0000
# Epoch 18/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0919 - accuracy: 0.9729 - true_positives_1: 1023.0000 - true_negatives_1: 1020.0000 - val_loss: 0.2171 - val_accuracy: 0.9244 - val_true_positives_1: 211.0000 - val_true_negatives_1: 205.0000
# Epoch 19/20
# 132/132 [==============================] - 7s 48ms/step - loss: 0.0825 - accuracy: 0.9738 - true_positives_1: 1021.0000 - true_negatives_1: 1024.0000 - val_loss: 0.2203 - val_accuracy: 0.9267 - val_true_positives_1: 206.0000 - val_true_negatives_1: 211.0000
# Epoch 20/20
# 132/132 [==============================] - 7s 48ms/step - loss: 0.0775 - accuracy: 0.9757 - true_positives_1: 1025.0000 - true_negatives_1: 1024.0000 - val_loss: 0.2492 - val_accuracy: 0.9178 - val_true_positives_1: 194.0000 - val_true_negatives_1: 219.0000

# %%
# test_loss, test_acc, true_pos, true_neg = model.evaluate(test_dataset)

# print(f"Test accuracy: {test_acc:.3f}",
#       f"\nTest loss: {test_loss:.3f}",
#       f"\nTrue positive: {true_pos:.3f}",
#       f"\nTest accuracy: {true_neg:.3f}")

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# adding 2 conv(64)

# %%
inputs = keras.Input(shape=INPUT_SHAPE)
#-----------------------------------------------------------------
x = inputs
x = layers.Rescaling(1./255)(inputs)
#---------------------------------------------------------------------------------------
x = layers.Conv2D(filters=8, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=16, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)

x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)

x = layers.Flatten()(x)
x = layers.Dense(16, activation="sigmoid")(x)

#kernel_regularizer=regularizers.l2(0.002)
#x = layers.Dropout(0.25)(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
               optimizer="rmsprop",
               metrics=["accuracy",tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives()])


history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = EPOCHS)
# Out:
# Epoch 1/20
# 132/132 [==============================] - 7s 41ms/step - loss: 0.5526 - accuracy: 0.6833 - true_positives_2: 530.0000 - true_negatives_2: 905.0000 - val_loss: 0.3824 - val_accuracy: 0.8444 - val_true_positives_2: 203.0000 - val_true_negatives_2: 177.0000
# Epoch 2/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.3413 - accuracy: 0.8600 - true_positives_2: 887.0000 - true_negatives_2: 919.0000 - val_loss: 0.3370 - val_accuracy: 0.8756 - val_true_positives_2: 179.0000 - val_true_negatives_2: 215.0000
# Epoch 3/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.2712 - accuracy: 0.8952 - true_positives_2: 933.0000 - true_negatives_2: 947.0000 - val_loss: 0.3161 - val_accuracy: 0.8667 - val_true_positives_2: 176.0000 - val_true_negatives_2: 214.0000
# Epoch 4/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.2332 - accuracy: 0.9143 - true_positives_2: 960.0000 - true_negatives_2: 960.0000 - val_loss: 0.3782 - val_accuracy: 0.8489 - val_true_positives_2: 162.0000 - val_true_negatives_2: 220.0000
# Epoch 5/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.1931 - accuracy: 0.9305 - true_positives_2: 976.0000 - true_negatives_2: 978.0000 - val_loss: 0.3026 - val_accuracy: 0.8667 - val_true_positives_2: 168.0000 - val_true_negatives_2: 222.0000
# Epoch 6/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.1719 - accuracy: 0.9386 - true_positives_2: 983.0000 - true_negatives_2: 988.0000 - val_loss: 0.2376 - val_accuracy: 0.9111 - val_true_positives_2: 194.0000 - val_true_negatives_2: 216.0000
# Epoch 7/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.1524 - accuracy: 0.9467 - true_positives_2: 991.0000 - true_negatives_2: 997.0000 - val_loss: 0.4528 - val_accuracy: 0.8467 - val_true_positives_2: 218.0000 - val_true_negatives_2: 163.0000
# Epoch 8/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1383 - accuracy: 0.9538 - true_positives_2: 1003.0000 - true_negatives_2: 1000.0000 - val_loss: 0.2136 - val_accuracy: 0.9178 - val_true_positives_2: 210.0000 - val_true_negatives_2: 203.0000
# Epoch 9/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1202 - accuracy: 0.9629 - true_positives_2: 1012.0000 - true_negatives_2: 1010.0000 - val_loss: 0.2421 - val_accuracy: 0.9267 - val_true_positives_2: 208.0000 - val_true_negatives_2: 209.0000
# Epoch 10/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1100 - accuracy: 0.9643 - true_positives_2: 1015.0000 - true_negatives_2: 1010.0000 - val_loss: 0.2552 - val_accuracy: 0.9244 - val_true_positives_2: 200.0000 - val_true_negatives_2: 216.0000
# Epoch 11/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1052 - accuracy: 0.9671 - true_positives_2: 1016.0000 - true_negatives_2: 1015.0000 - val_loss: 0.2864 - val_accuracy: 0.9200 - val_true_positives_2: 197.0000 - val_true_negatives_2: 217.0000
# Epoch 12/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.0912 - accuracy: 0.9714 - true_positives_2: 1017.0000 - true_negatives_2: 1023.0000 - val_loss: 0.2378 - val_accuracy: 0.9244 - val_true_positives_2: 199.0000 - val_true_negatives_2: 217.0000
# Epoch 13/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.0848 - accuracy: 0.9729 - true_positives_2: 1030.0000 - true_negatives_2: 1013.0000 - val_loss: 0.2339 - val_accuracy: 0.9244 - val_true_positives_2: 206.0000 - val_true_negatives_2: 210.0000
# Epoch 14/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0774 - accuracy: 0.9771 - true_positives_2: 1028.0000 - true_negatives_2: 1024.0000 - val_loss: 0.2311 - val_accuracy: 0.9356 - val_true_positives_2: 206.0000 - val_true_negatives_2: 215.0000
# Epoch 15/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.0640 - accuracy: 0.9838 - true_positives_2: 1034.0000 - true_negatives_2: 1032.0000 - val_loss: 0.2651 - val_accuracy: 0.9133 - val_true_positives_2: 194.0000 - val_true_negatives_2: 217.0000
# Epoch 16/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.0584 - accuracy: 0.9833 - true_positives_2: 1033.0000 - true_negatives_2: 1032.0000 - val_loss: 0.2708 - val_accuracy: 0.9356 - val_true_positives_2: 203.0000 - val_true_negatives_2: 218.0000
# Epoch 17/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.0450 - accuracy: 0.9867 - true_positives_2: 1035.0000 - true_negatives_2: 1037.0000 - val_loss: 0.4549 - val_accuracy: 0.9000 - val_true_positives_2: 182.0000 - val_true_negatives_2: 223.0000
# Epoch 18/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0600 - accuracy: 0.9819 - true_positives_2: 1031.0000 - true_negatives_2: 1031.0000 - val_loss: 0.2814 - val_accuracy: 0.9311 - val_true_positives_2: 203.0000 - val_true_negatives_2: 216.0000
# Epoch 19/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0482 - accuracy: 0.9857 - true_positives_2: 1039.0000 - true_negatives_2: 1031.0000 - val_loss: 0.4610 - val_accuracy: 0.9000 - val_true_positives_2: 182.0000 - val_true_negatives_2: 223.0000
# Epoch 20/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.0468 - accuracy: 0.9862 - true_positives_2: 1036.0000 - true_negatives_2: 1035.0000 - val_loss: 0.3019 - val_accuracy: 0.9333 - val_true_positives_2: 208.0000 - val_true_negatives_2: 212.0000

# %%
# test_loss, test_acc, true_pos, true_neg = model.evaluate(test_dataset)

# print(f"Test accuracy: {test_acc:.3f}",
#       f"\nTest loss: {test_loss:.3f}",
#       f"\nTrue positive: {true_pos:.3f}",
#       f"\nTest accuracy: {true_neg:.3f}")

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# remove 1 max pool add 3 conv

# %%
inputs = keras.Input(shape=INPUT_SHAPE)

x = inputs
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=8, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=16, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
#x = layers.MaxPooling2D(pool_size=2)(x) DELETED LAYER
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)

x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x) #ADDED
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x) #ADDED
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x) #ADDED


x = layers.Flatten()(x)
x = layers.Dense(32, activation="sigmoid")(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
               optimizer="rmsprop",
               metrics=["accuracy",tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives()])


history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = EPOCHS)
# Out:
# Epoch 1/20
# 132/132 [==============================] - 8s 44ms/step - loss: 0.6685 - accuracy: 0.6119 - true_positives_4: 830.0000 - true_negatives_4: 455.0000 - val_loss: 0.3999 - val_accuracy: 0.8400 - val_true_positives_4: 168.0000 - val_true_negatives_4: 210.0000
# Epoch 2/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.4531 - accuracy: 0.8000 - true_positives_4: 823.0000 - true_negatives_4: 857.0000 - val_loss: 0.3255 - val_accuracy: 0.8600 - val_true_positives_4: 201.0000 - val_true_negatives_4: 186.0000
# Epoch 3/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.3586 - accuracy: 0.8490 - true_positives_4: 881.0000 - true_negatives_4: 902.0000 - val_loss: 0.2901 - val_accuracy: 0.8933 - val_true_positives_4: 207.0000 - val_true_negatives_4: 195.0000
# Epoch 4/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.2971 - accuracy: 0.8719 - true_positives_4: 914.0000 - true_negatives_4: 917.0000 - val_loss: 0.3054 - val_accuracy: 0.8778 - val_true_positives_4: 183.0000 - val_true_negatives_4: 212.0000
# Epoch 5/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.2664 - accuracy: 0.8900 - true_positives_4: 925.0000 - true_negatives_4: 944.0000 - val_loss: 0.3703 - val_accuracy: 0.8422 - val_true_positives_4: 157.0000 - val_true_negatives_4: 222.0000
# Epoch 6/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.2439 - accuracy: 0.9095 - true_positives_4: 959.0000 - true_negatives_4: 951.0000 - val_loss: 0.2445 - val_accuracy: 0.8978 - val_true_positives_4: 203.0000 - val_true_negatives_4: 201.0000
# Epoch 7/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.2206 - accuracy: 0.9162 - true_positives_4: 964.0000 - true_negatives_4: 960.0000 - val_loss: 0.2255 - val_accuracy: 0.9267 - val_true_positives_4: 210.0000 - val_true_negatives_4: 207.0000
# Epoch 8/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.2088 - accuracy: 0.9238 - true_positives_4: 959.0000 - true_negatives_4: 981.0000 - val_loss: 0.1861 - val_accuracy: 0.9422 - val_true_positives_4: 210.0000 - val_true_negatives_4: 214.0000
# Epoch 9/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1829 - accuracy: 0.9314 - true_positives_4: 978.0000 - true_negatives_4: 978.0000 - val_loss: 0.2166 - val_accuracy: 0.9178 - val_true_positives_4: 200.0000 - val_true_negatives_4: 213.0000
# Epoch 10/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1983 - accuracy: 0.9200 - true_positives_4: 973.0000 - true_negatives_4: 959.0000 - val_loss: 0.2922 - val_accuracy: 0.8889 - val_true_positives_4: 184.0000 - val_true_negatives_4: 216.0000
# Epoch 11/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.1880 - accuracy: 0.9305 - true_positives_4: 991.0000 - true_negatives_4: 963.0000 - val_loss: 0.2134 - val_accuracy: 0.9289 - val_true_positives_4: 200.0000 - val_true_negatives_4: 218.0000
# Epoch 12/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.1796 - accuracy: 0.9333 - true_positives_4: 989.0000 - true_negatives_4: 971.0000 - val_loss: 0.2011 - val_accuracy: 0.9356 - val_true_positives_4: 205.0000 - val_true_negatives_4: 216.0000
# Epoch 13/20
# 132/132 [==============================] - 6s 47ms/step - loss: 0.1689 - accuracy: 0.9371 - true_positives_4: 988.0000 - true_negatives_4: 980.0000 - val_loss: 0.2082 - val_accuracy: 0.9267 - val_true_positives_4: 208.0000 - val_true_negatives_4: 209.0000
# Epoch 14/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.1809 - accuracy: 0.9324 - true_positives_4: 988.0000 - true_negatives_4: 970.0000 - val_loss: 0.2111 - val_accuracy: 0.9111 - val_true_positives_4: 200.0000 - val_true_negatives_4: 210.0000
# Epoch 15/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1635 - accuracy: 0.9357 - true_positives_4: 991.0000 - true_negatives_4: 974.0000 - val_loss: 0.2819 - val_accuracy: 0.8822 - val_true_positives_4: 177.0000 - val_true_negatives_4: 220.0000
# Epoch 16/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.1594 - accuracy: 0.9424 - true_positives_4: 1004.0000 - true_negatives_4: 975.0000 - val_loss: 0.2533 - val_accuracy: 0.9178 - val_true_positives_4: 202.0000 - val_true_negatives_4: 211.0000
# Epoch 17/20
# 132/132 [==============================] - 6s 47ms/step - loss: 0.1693 - accuracy: 0.9424 - true_positives_4: 1007.0000 - true_negatives_4: 972.0000 - val_loss: 0.2177 - val_accuracy: 0.9267 - val_true_positives_4: 210.0000 - val_true_negatives_4: 207.0000
# Epoch 18/20
# 132/132 [==============================] - 6s 47ms/step - loss: 0.1780 - accuracy: 0.9362 - true_positives_4: 993.0000 - true_negatives_4: 973.0000 - val_loss: 0.1990 - val_accuracy: 0.9356 - val_true_positives_4: 207.0000 - val_true_negatives_4: 214.0000
# Epoch 19/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1836 - accuracy: 0.9329 - true_positives_4: 988.0000 - true_negatives_4: 971.0000 - val_loss: 0.2089 - val_accuracy: 0.9222 - val_true_positives_4: 202.0000 - val_true_negatives_4: 213.0000
# Epoch 20/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.1678 - accuracy: 0.9386 - true_positives_4: 971.0000 - true_negatives_4: 1000.0000 - val_loss: 0.2409 - val_accuracy: 0.9311 - val_true_positives_4: 208.0000 - val_true_negatives_4: 211.0000

# %%
# test_loss, test_acc, true_pos, true_neg = model.evaluate(test_dataset)

# print(f"Test accuracy: {test_acc:.3f}",
#       f"\nTest loss: {test_loss:.3f}",
#       f"\nTrue positive: {true_pos:.3f}",
#       f"\nTest accuracy: {true_neg:.3f}")

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# remove 1 max pool add 4 conv

# %%
inputs = keras.Input(shape=INPUT_SHAPE)
#-----------------------------------------------------------------
x = inputs
x = layers.Rescaling(1./255)(inputs)
#---------------------------------------------------------------------------------------
x = layers.Conv2D(filters=8, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=16, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
#x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)

x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)

x = layers.Flatten()(x)
x = layers.Dense(32, activation="sigmoid")(x)

#kernel_regularizer=regularizers.l2(0.002)
#x = layers.Dropout(0.25)(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
               optimizer="rmsprop",
               metrics=["accuracy",tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives()])


history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = EPOCHS)
# Out:
# Epoch 1/20
# 132/132 [==============================] - 8s 45ms/step - loss: 0.7033 - accuracy: 0.5514 - true_positives_5: 328.0000 - true_negatives_5: 830.0000 - val_loss: 0.6376 - val_accuracy: 0.5378 - val_true_positives_5: 17.0000 - val_true_negatives_5: 225.0000
# Epoch 2/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.5561 - accuracy: 0.7267 - true_positives_5: 742.0000 - true_negatives_5: 784.0000 - val_loss: 0.6487 - val_accuracy: 0.7356 - val_true_positives_5: 107.0000 - val_true_negatives_5: 224.0000
# Epoch 3/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.3762 - accuracy: 0.8324 - true_positives_5: 843.0000 - true_negatives_5: 905.0000 - val_loss: 0.3577 - val_accuracy: 0.8511 - val_true_positives_5: 209.0000 - val_true_negatives_5: 174.0000
# Epoch 4/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.3091 - accuracy: 0.8743 - true_positives_5: 908.0000 - true_negatives_5: 928.0000 - val_loss: 0.3665 - val_accuracy: 0.8333 - val_true_positives_5: 211.0000 - val_true_negatives_5: 164.0000
# Epoch 5/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.2665 - accuracy: 0.8962 - true_positives_5: 943.0000 - true_negatives_5: 939.0000 - val_loss: 0.6476 - val_accuracy: 0.7511 - val_true_positives_5: 114.0000 - val_true_negatives_5: 224.0000
# Epoch 6/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.2816 - accuracy: 0.8881 - true_positives_5: 931.0000 - true_negatives_5: 934.0000 - val_loss: 0.2847 - val_accuracy: 0.8933 - val_true_positives_5: 183.0000 - val_true_negatives_5: 219.0000
# Epoch 7/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.2690 - accuracy: 0.8971 - true_positives_5: 952.0000 - true_negatives_5: 932.0000 - val_loss: 0.8809 - val_accuracy: 0.7333 - val_true_positives_5: 221.0000 - val_true_negatives_5: 109.0000
# Epoch 8/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.2374 - accuracy: 0.9157 - true_positives_5: 958.0000 - true_negatives_5: 965.0000 - val_loss: 0.2444 - val_accuracy: 0.9067 - val_true_positives_5: 212.0000 - val_true_negatives_5: 196.0000
# Epoch 9/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.2449 - accuracy: 0.9124 - true_positives_5: 970.0000 - true_negatives_5: 946.0000 - val_loss: 0.5643 - val_accuracy: 0.8267 - val_true_positives_5: 149.0000 - val_true_negatives_5: 223.0000
# Epoch 10/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.2200 - accuracy: 0.9210 - true_positives_5: 966.0000 - true_negatives_5: 968.0000 - val_loss: 0.2314 - val_accuracy: 0.9178 - val_true_positives_5: 195.0000 - val_true_negatives_5: 218.0000
# Epoch 11/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.2244 - accuracy: 0.9200 - true_positives_5: 962.0000 - true_negatives_5: 970.0000 - val_loss: 0.2892 - val_accuracy: 0.9044 - val_true_positives_5: 192.0000 - val_true_negatives_5: 215.0000
# Epoch 12/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.2250 - accuracy: 0.9224 - true_positives_5: 965.0000 - true_negatives_5: 972.0000 - val_loss: 0.2622 - val_accuracy: 0.9089 - val_true_positives_5: 189.0000 - val_true_negatives_5: 220.0000
# Epoch 13/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.2451 - accuracy: 0.9076 - true_positives_5: 959.0000 - true_negatives_5: 947.0000 - val_loss: 0.4298 - val_accuracy: 0.8511 - val_true_positives_5: 222.0000 - val_true_negatives_5: 161.0000
# Epoch 14/20
# 132/132 [==============================] - 6s 47ms/step - loss: 0.2196 - accuracy: 0.9143 - true_positives_5: 967.0000 - true_negatives_5: 953.0000 - val_loss: 0.4581 - val_accuracy: 0.8400 - val_true_positives_5: 156.0000 - val_true_negatives_5: 222.0000
# Epoch 15/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.2071 - accuracy: 0.9152 - true_positives_5: 958.0000 - true_negatives_5: 964.0000 - val_loss: 0.2474 - val_accuracy: 0.9022 - val_true_positives_5: 186.0000 - val_true_negatives_5: 220.0000
# Epoch 16/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.2060 - accuracy: 0.9233 - true_positives_5: 964.0000 - true_negatives_5: 975.0000 - val_loss: 0.2566 - val_accuracy: 0.9133 - val_true_positives_5: 194.0000 - val_true_negatives_5: 217.0000
# Epoch 17/20
# 132/132 [==============================] - 6s 47ms/step - loss: 0.2080 - accuracy: 0.9181 - true_positives_5: 962.0000 - true_negatives_5: 966.0000 - val_loss: 0.2877 - val_accuracy: 0.8844 - val_true_positives_5: 202.0000 - val_true_negatives_5: 196.0000
# Epoch 18/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.2519 - accuracy: 0.9000 - true_positives_5: 937.0000 - true_negatives_5: 953.0000 - val_loss: 0.2432 - val_accuracy: 0.9156 - val_true_positives_5: 216.0000 - val_true_negatives_5: 196.0000
# Epoch 19/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.2276 - accuracy: 0.9171 - true_positives_5: 980.0000 - true_negatives_5: 946.0000 - val_loss: 0.2392 - val_accuracy: 0.9089 - val_true_positives_5: 209.0000 - val_true_negatives_5: 200.0000
# Epoch 20/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.2220 - accuracy: 0.9186 - true_positives_5: 950.0000 - true_negatives_5: 979.0000 - val_loss: 0.2506 - val_accuracy: 0.9000 - val_true_positives_5: 196.0000 - val_true_negatives_5: 209.0000

# %%
# test_loss, test_acc, true_pos, true_neg = model.evaluate(test_dataset)

# print(f"Test accuracy: {test_acc:.3f}",
#       f"\nTest loss: {test_loss:.3f}",
#       f"\nTrue positive: {true_pos:.3f}",
#       f"\nTest accuracy: {true_neg:.3f}")

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# remove 2 max pool add 8 conv

# %%
inputs = keras.Input(shape=INPUT_SHAPE)
#-----------------------------------------------------------------
x = inputs
x = layers.Rescaling(1./255)(inputs)
#---------------------------------------------------------------------------------------
x = layers.Conv2D(filters=8, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=16, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
#x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
#x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)

x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)

x = layers.Flatten()(x)
x = layers.Dense(32, activation="sigmoid")(x)

#kernel_regularizer=regularizers.l2(0.002)
#x = layers.Dropout(0.25)(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
               optimizer="rmsprop",
               metrics=["accuracy",tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives()])


history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = EPOCHS)
# Out:
# Epoch 1/20
# 132/132 [==============================] - 9s 49ms/step - loss: 0.6978 - accuracy: 0.4905 - true_positives_8: 270.0000 - true_negatives_8: 760.0000 - val_loss: 0.6934 - val_accuracy: 0.5000 - val_true_positives_8: 225.0000 - val_true_negatives_8: 0.0000e+00
# Epoch 2/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.9940 - accuracy: 0.4943 - true_positives_8: 370.0000 - true_negatives_8: 668.0000 - val_loss: 1.1637 - val_accuracy: 0.5000 - val_true_positives_8: 0.0000e+00 - val_true_negatives_8: 225.0000
# Epoch 3/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.8817 - accuracy: 0.5000 - true_positives_8: 0.0000e+00 - true_negatives_8: 1050.0000 - val_loss: 0.7077 - val_accuracy: 0.5000 - val_true_positives_8: 0.0000e+00 - val_true_negatives_8: 225.0000
# Epoch 4/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.6962 - accuracy: 0.4962 - true_positives_8: 76.0000 - true_negatives_8: 966.0000 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_true_positives_8: 225.0000 - val_true_negatives_8: 0.0000e+00
# Epoch 5/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.6941 - accuracy: 0.4762 - true_positives_8: 409.0000 - true_negatives_8: 591.0000 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_true_positives_8: 225.0000 - val_true_negatives_8: 0.0000e+00
# Epoch 6/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.6939 - accuracy: 0.4819 - true_positives_8: 453.0000 - true_negatives_8: 559.0000 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_true_positives_8: 0.0000e+00 - val_true_negatives_8: 225.0000
# Epoch 7/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.6939 - accuracy: 0.4914 - true_positives_8: 401.0000 - true_negatives_8: 631.0000 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_true_positives_8: 0.0000e+00 - val_true_negatives_8: 225.0000
# Epoch 8/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.6938 - accuracy: 0.4952 - true_positives_8: 397.0000 - true_negatives_8: 643.0000 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_true_positives_8: 0.0000e+00 - val_true_negatives_8: 225.0000
# Epoch 9/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.6937 - accuracy: 0.4876 - true_positives_8: 445.0000 - true_negatives_8: 579.0000 - val_loss: 0.6934 - val_accuracy: 0.5000 - val_true_positives_8: 225.0000 - val_true_negatives_8: 0.0000e+00
# Epoch 10/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.6940 - accuracy: 0.4962 - true_positives_8: 678.0000 - true_negatives_8: 364.0000 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_true_positives_8: 225.0000 - val_true_negatives_8: 0.0000e+00
# Epoch 11/20
# 132/132 [==============================] - 7s 48ms/step - loss: 0.6939 - accuracy: 0.4733 - true_positives_8: 542.0000 - true_negatives_8: 452.0000 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_true_positives_8: 0.0000e+00 - val_true_negatives_8: 225.0000
# Epoch 12/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.6938 - accuracy: 0.5000 - true_positives_8: 498.0000 - true_negatives_8: 552.0000 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_true_positives_8: 225.0000 - val_true_negatives_8: 0.0000e+00
# Epoch 13/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.6938 - accuracy: 0.4829 - true_positives_8: 656.0000 - true_negatives_8: 358.0000 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_true_positives_8: 0.0000e+00 - val_true_negatives_8: 225.0000
# Epoch 14/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.6939 - accuracy: 0.4867 - true_positives_8: 460.0000 - true_negatives_8: 562.0000 - val_loss: 0.6933 - val_accuracy: 0.5000 - val_true_positives_8: 225.0000 - val_true_negatives_8: 0.0000e+00
# Epoch 15/20
# 132/132 [==============================] - 6s 47ms/step - loss: 0.6937 - accuracy: 0.5076 - true_positives_8: 546.0000 - true_negatives_8: 520.0000 - val_loss: 0.6936 - val_accuracy: 0.5000 - val_true_positives_8: 225.0000 - val_true_negatives_8: 0.0000e+00
# Epoch 16/20
# 132/132 [==============================] - 7s 47ms/step - loss: 0.6941 - accuracy: 0.4857 - true_positives_8: 619.0000 - true_negatives_8: 401.0000 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_true_positives_8: 225.0000 - val_true_negatives_8: 0.0000e+00
# Epoch 17/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.6940 - accuracy: 0.4867 - true_positives_8: 484.0000 - true_negatives_8: 538.0000 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_true_positives_8: 225.0000 - val_true_negatives_8: 0.0000e+00
# Epoch 18/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.6941 - accuracy: 0.4848 - true_positives_8: 586.0000 - true_negatives_8: 432.0000 - val_loss: 0.6934 - val_accuracy: 0.5000 - val_true_positives_8: 225.0000 - val_true_negatives_8: 0.0000e+00
# Epoch 19/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.6941 - accuracy: 0.4790 - true_positives_8: 596.0000 - true_negatives_8: 410.0000 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_true_positives_8: 225.0000 - val_true_negatives_8: 0.0000e+00
# Epoch 20/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.6937 - accuracy: 0.4943 - true_positives_8: 404.0000 - true_negatives_8: 634.0000 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_true_positives_8: 0.0000e+00 - val_true_negatives_8: 225.0000

# %%
# test_loss, test_acc, true_pos, true_neg = model.evaluate(test_dataset)

# print(f"Test accuracy: {test_acc:.3f}",
#       f"\nTest loss: {test_loss:.3f}",
#       f"\nTrue positive: {true_pos:.3f}",
#       f"\nTest accuracy: {true_neg:.3f}")

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()
