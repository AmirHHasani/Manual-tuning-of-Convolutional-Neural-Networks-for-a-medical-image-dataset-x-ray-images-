# %%
import tensorflow as tf
from tensorflow import keras
from keras import optimizers

from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense, AvgPool2D,MaxPool2D
from keras.models import Sequential, Model

from tensorflow.keras.optimizers import Adam, SGD, RMSprop

from tensorflow.keras import layers
from tensorflow.keras import regularizers

import matplotlib.pyplot as plt

from tensorflow.keras.utils import image_dataset_from_directory

import numpy as np

# %%
IMG_W = 150
IMG_H = 150
CHANNELS = 3

INPUT_SHAPE = (IMG_W, IMG_H, CHANNELS)
NB_CLASSES = 2
EPOCHS = 20
BATCH_SIZE = 16

# %%
new_base_dir = "./2-step/split data"

# %%
train_dataset = image_dataset_from_directory(
new_base_dir + "/train",
image_size=(IMG_W, IMG_W),
batch_size=BATCH_SIZE
)

validation_dataset = image_dataset_from_directory(
new_base_dir + "/val",
image_size=(IMG_W, IMG_W),
batch_size=BATCH_SIZE,
)

test_dataset = image_dataset_from_directory(
new_base_dir + "/test",
image_size=(IMG_W, IMG_W),
batch_size=BATCH_SIZE
)
# Out:
# Found 2100 files belonging to 2 classes.
# Found 450 files belonging to 2 classes.
# Found 450 files belonging to 2 classes.

# %%
# base model

# %%
inputs = keras.Input(shape=INPUT_SHAPE)
#-----------------------------------------------------------------
x = inputs
x = layers.Rescaling(1./255)(inputs)
#---------------------------------------------------------------------------------------
x = layers.Conv2D(filters=8, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=16, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)

x = layers.Flatten()(x)
x = layers.Dense(8, activation="sigmoid")(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
               optimizer="rmsprop",
               metrics=["accuracy",tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives()])


history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = EPOCHS)
# Out:
# Epoch 1/20
# 132/132 [==============================] - 10s 48ms/step - loss: 0.4868 - accuracy: 0.7657 - true_positives: 695.0000 - true_negatives: 913.0000 - val_loss: 0.3728 - val_accuracy: 0.8444 - val_true_positives: 205.0000 - val_true_negatives: 175.0000
# Epoch 2/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.3415 - accuracy: 0.8767 - true_positives: 909.0000 - true_negatives: 932.0000 - val_loss: 0.3864 - val_accuracy: 0.8333 - val_true_positives: 207.0000 - val_true_negatives: 168.0000
# Epoch 3/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.3051 - accuracy: 0.8857 - true_positives: 910.0000 - true_negatives: 950.0000 - val_loss: 0.3429 - val_accuracy: 0.8600 - val_true_positives: 169.0000 - val_true_negatives: 218.0000
# Epoch 4/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.2699 - accuracy: 0.8995 - true_positives: 924.0000 - true_negatives: 965.0000 - val_loss: 0.3145 - val_accuracy: 0.8778 - val_true_positives: 180.0000 - val_true_negatives: 215.0000
# Epoch 5/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.2333 - accuracy: 0.9171 - true_positives: 953.0000 - true_negatives: 973.0000 - val_loss: 0.2771 - val_accuracy: 0.8956 - val_true_positives: 192.0000 - val_true_negatives: 211.0000
# Epoch 6/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.2046 - accuracy: 0.9324 - true_positives: 979.0000 - true_negatives: 979.0000 - val_loss: 0.2682 - val_accuracy: 0.9044 - val_true_positives: 197.0000 - val_true_negatives: 210.0000
# Epoch 7/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1825 - accuracy: 0.9390 - true_positives: 987.0000 - true_negatives: 985.0000 - val_loss: 0.2502 - val_accuracy: 0.9111 - val_true_positives: 210.0000 - val_true_negatives: 200.0000
# Epoch 8/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.1698 - accuracy: 0.9486 - true_positives: 1001.0000 - true_negatives: 991.0000 - val_loss: 0.2544 - val_accuracy: 0.9067 - val_true_positives: 197.0000 - val_true_negatives: 211.0000
# Epoch 9/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1529 - accuracy: 0.9476 - true_positives: 994.0000 - true_negatives: 996.0000 - val_loss: 0.2249 - val_accuracy: 0.9222 - val_true_positives: 201.0000 - val_true_negatives: 214.0000
# Epoch 10/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.1519 - accuracy: 0.9457 - true_positives: 997.0000 - true_negatives: 989.0000 - val_loss: 0.2346 - val_accuracy: 0.9111 - val_true_positives: 203.0000 - val_true_negatives: 207.0000
# Epoch 11/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1345 - accuracy: 0.9600 - true_positives: 1005.0000 - true_negatives: 1011.0000 - val_loss: 0.2300 - val_accuracy: 0.9156 - val_true_positives: 202.0000 - val_true_negatives: 210.0000
# Epoch 12/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.1199 - accuracy: 0.9614 - true_positives: 1012.0000 - true_negatives: 1007.0000 - val_loss: 0.2975 - val_accuracy: 0.8756 - val_true_positives: 213.0000 - val_true_negatives: 181.0000
# Epoch 13/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1168 - accuracy: 0.9657 - true_positives: 1015.0000 - true_negatives: 1013.0000 - val_loss: 0.2392 - val_accuracy: 0.9133 - val_true_positives: 204.0000 - val_true_negatives: 207.0000
# Epoch 14/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1019 - accuracy: 0.9657 - true_positives: 1016.0000 - true_negatives: 1012.0000 - val_loss: 0.2275 - val_accuracy: 0.9222 - val_true_positives: 206.0000 - val_true_negatives: 209.0000
# Epoch 15/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0937 - accuracy: 0.9729 - true_positives: 1019.0000 - true_negatives: 1024.0000 - val_loss: 0.2333 - val_accuracy: 0.9222 - val_true_positives: 199.0000 - val_true_negatives: 216.0000
# Epoch 16/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.0880 - accuracy: 0.9733 - true_positives: 1022.0000 - true_negatives: 1022.0000 - val_loss: 0.3064 - val_accuracy: 0.9044 - val_true_positives: 189.0000 - val_true_negatives: 218.0000
# Epoch 17/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0801 - accuracy: 0.9752 - true_positives: 1025.0000 - true_negatives: 1023.0000 - val_loss: 0.2608 - val_accuracy: 0.9244 - val_true_positives: 196.0000 - val_true_negatives: 220.0000
# Epoch 18/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0754 - accuracy: 0.9757 - true_positives: 1027.0000 - true_negatives: 1022.0000 - val_loss: 0.2816 - val_accuracy: 0.9244 - val_true_positives: 196.0000 - val_true_negatives: 220.0000
# Epoch 19/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.0670 - accuracy: 0.9800 - true_positives: 1030.0000 - true_negatives: 1028.0000 - val_loss: 0.2547 - val_accuracy: 0.9244 - val_true_positives: 199.0000 - val_true_negatives: 217.0000
# Epoch 20/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0582 - accuracy: 0.9848 - true_positives: 1035.0000 - true_negatives: 1033.0000 - val_loss: 0.3681 - val_accuracy: 0.9067 - val_true_positives: 189.0000 - val_true_negatives: 219.0000

# %%
# test_loss, test_acc, true_pos, true_neg = model.evaluate(test_dataset)

# print(f"Test accuracy: {test_acc:.3f}",
#       f"\nTest loss: {test_loss:.3f}",
#       f"\nTrue positive: {true_pos:.3f}",
#       f"\nTest accuracy: {true_neg:.3f}")

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# kernel size = 2

# %%
inputs = keras.Input(shape=INPUT_SHAPE)
#-----------------------------------------------------------------
x = inputs
x = layers.Rescaling(1./255)(inputs)
#---------------------------------------------------------------------------------------
x = layers.Conv2D(filters=8, kernel_size=2, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=16, kernel_size=2, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=32, kernel_size=2, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=2, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=2, activation="relu")(x)

x = layers.Flatten()(x)
x = layers.Dense(8, activation="sigmoid")(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
               optimizer="rmsprop",
               metrics=["accuracy",tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives()])


history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = EPOCHS)
# Out:
# Epoch 1/20
# 132/132 [==============================] - 7s 43ms/step - loss: 0.5026 - accuracy: 0.7690 - true_positives_2: 682.0000 - true_negatives_2: 933.0000 - val_loss: 0.3300 - val_accuracy: 0.9089 - val_true_positives_2: 197.0000 - val_true_negatives_2: 212.0000
# Epoch 2/20
# 132/132 [==============================] - 6s 40ms/step - loss: 0.3024 - accuracy: 0.9119 - true_positives_2: 953.0000 - true_negatives_2: 962.0000 - val_loss: 0.3049 - val_accuracy: 0.8956 - val_true_positives_2: 185.0000 - val_true_negatives_2: 218.0000
# Epoch 3/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.2512 - accuracy: 0.9290 - true_positives_2: 972.0000 - true_negatives_2: 979.0000 - val_loss: 0.2904 - val_accuracy: 0.8978 - val_true_positives_2: 184.0000 - val_true_negatives_2: 220.0000
# Epoch 4/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.2188 - accuracy: 0.9295 - true_positives_2: 977.0000 - true_negatives_2: 975.0000 - val_loss: 0.2361 - val_accuracy: 0.9222 - val_true_positives_2: 199.0000 - val_true_negatives_2: 216.0000
# Epoch 5/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1956 - accuracy: 0.9414 - true_positives_2: 990.0000 - true_negatives_2: 987.0000 - val_loss: 0.2147 - val_accuracy: 0.9311 - val_true_positives_2: 216.0000 - val_true_negatives_2: 203.0000
# Epoch 6/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.1820 - accuracy: 0.9429 - true_positives_2: 999.0000 - true_negatives_2: 981.0000 - val_loss: 0.2079 - val_accuracy: 0.9333 - val_true_positives_2: 214.0000 - val_true_negatives_2: 206.0000
# Epoch 7/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1700 - accuracy: 0.9471 - true_positives_2: 999.0000 - true_negatives_2: 990.0000 - val_loss: 0.2343 - val_accuracy: 0.9133 - val_true_positives_2: 218.0000 - val_true_negatives_2: 193.0000
# Epoch 8/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.1547 - accuracy: 0.9505 - true_positives_2: 1003.0000 - true_negatives_2: 993.0000 - val_loss: 0.2017 - val_accuracy: 0.9311 - val_true_positives_2: 205.0000 - val_true_negatives_2: 214.0000
# Epoch 9/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.1438 - accuracy: 0.9533 - true_positives_2: 1007.0000 - true_negatives_2: 995.0000 - val_loss: 0.2212 - val_accuracy: 0.9289 - val_true_positives_2: 198.0000 - val_true_negatives_2: 220.0000
# Epoch 10/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1347 - accuracy: 0.9543 - true_positives_2: 1002.0000 - true_negatives_2: 1002.0000 - val_loss: 0.1858 - val_accuracy: 0.9333 - val_true_positives_2: 206.0000 - val_true_negatives_2: 214.0000
# Epoch 11/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1277 - accuracy: 0.9595 - true_positives_2: 1010.0000 - true_negatives_2: 1005.0000 - val_loss: 0.2052 - val_accuracy: 0.9333 - val_true_positives_2: 203.0000 - val_true_negatives_2: 217.0000
# Epoch 12/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1191 - accuracy: 0.9652 - true_positives_2: 1014.0000 - true_negatives_2: 1013.0000 - val_loss: 0.2272 - val_accuracy: 0.9289 - val_true_positives_2: 200.0000 - val_true_negatives_2: 218.0000
# Epoch 13/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1153 - accuracy: 0.9633 - true_positives_2: 1014.0000 - true_negatives_2: 1009.0000 - val_loss: 0.1853 - val_accuracy: 0.9422 - val_true_positives_2: 210.0000 - val_true_negatives_2: 214.0000
# Epoch 14/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.1024 - accuracy: 0.9686 - true_positives_2: 1018.0000 - true_negatives_2: 1016.0000 - val_loss: 0.1998 - val_accuracy: 0.9333 - val_true_positives_2: 207.0000 - val_true_negatives_2: 213.0000
# Epoch 15/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0995 - accuracy: 0.9695 - true_positives_2: 1018.0000 - true_negatives_2: 1018.0000 - val_loss: 0.2410 - val_accuracy: 0.9311 - val_true_positives_2: 201.0000 - val_true_negatives_2: 218.0000
# Epoch 16/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.0921 - accuracy: 0.9748 - true_positives_2: 1025.0000 - true_negatives_2: 1022.0000 - val_loss: 0.2216 - val_accuracy: 0.9378 - val_true_positives_2: 204.0000 - val_true_negatives_2: 218.0000
# Epoch 17/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0909 - accuracy: 0.9710 - true_positives_2: 1022.0000 - true_negatives_2: 1017.0000 - val_loss: 0.4520 - val_accuracy: 0.8533 - val_true_positives_2: 163.0000 - val_true_negatives_2: 221.0000
# Epoch 18/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0830 - accuracy: 0.9738 - true_positives_2: 1020.0000 - true_negatives_2: 1025.0000 - val_loss: 0.2034 - val_accuracy: 0.9356 - val_true_positives_2: 205.0000 - val_true_negatives_2: 216.0000
# Epoch 19/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.0814 - accuracy: 0.9719 - true_positives_2: 1023.0000 - true_negatives_2: 1018.0000 - val_loss: 0.1946 - val_accuracy: 0.9378 - val_true_positives_2: 208.0000 - val_true_negatives_2: 214.0000
# Epoch 20/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.0655 - accuracy: 0.9824 - true_positives_2: 1032.0000 - true_negatives_2: 1031.0000 - val_loss: 0.1957 - val_accuracy: 0.9400 - val_true_positives_2: 211.0000 - val_true_negatives_2: 212.0000

# %%
# test_loss, test_acc, true_pos, true_neg = model.evaluate(test_dataset)

# print(f"Test accuracy: {test_acc:.3f}",
#       f"\nTest loss: {test_loss:.3f}",
#       f"\nTrue positive: {true_pos:.3f}",
#       f"\nTest accuracy: {true_neg:.3f}")

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# kernel size = 4

# %%
inputs = keras.Input(shape=INPUT_SHAPE)
#-----------------------------------------------------------------
x = inputs
x = layers.Rescaling(1./255)(inputs)
#---------------------------------------------------------------------------------------
x = layers.Conv2D(filters=8, kernel_size=4, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=16, kernel_size=4, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=32, kernel_size=4, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=4, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=4, activation="relu")(x)

x = layers.Flatten()(x)
x = layers.Dense(8, activation="sigmoid")(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
               optimizer="rmsprop",
               metrics=["accuracy",tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives()])


history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = EPOCHS)
# Out:
# Epoch 1/20
# 132/132 [==============================] - 8s 47ms/step - loss: 0.5625 - accuracy: 0.7010 - true_positives_3: 639.0000 - true_negatives_3: 833.0000 - val_loss: 0.4683 - val_accuracy: 0.8444 - val_true_positives_3: 172.0000 - val_true_negatives_3: 208.0000
# Epoch 2/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.4265 - accuracy: 0.8329 - true_positives_3: 869.0000 - true_negatives_3: 880.0000 - val_loss: 0.4440 - val_accuracy: 0.8200 - val_true_positives_3: 145.0000 - val_true_negatives_3: 224.0000
# Epoch 3/20
# 132/132 [==============================] - 7s 51ms/step - loss: 0.3533 - accuracy: 0.8781 - true_positives_3: 916.0000 - true_negatives_3: 928.0000 - val_loss: 0.3339 - val_accuracy: 0.8844 - val_true_positives_3: 177.0000 - val_true_negatives_3: 221.0000
# Epoch 4/20
# 132/132 [==============================] - 7s 49ms/step - loss: 0.3117 - accuracy: 0.8905 - true_positives_3: 935.0000 - true_negatives_3: 935.0000 - val_loss: 0.4927 - val_accuracy: 0.7756 - val_true_positives_3: 216.0000 - val_true_negatives_3: 133.0000
# Epoch 5/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.2793 - accuracy: 0.9052 - true_positives_3: 955.0000 - true_negatives_3: 946.0000 - val_loss: 0.3639 - val_accuracy: 0.8600 - val_true_positives_3: 164.0000 - val_true_negatives_3: 223.0000
# Epoch 6/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.2566 - accuracy: 0.9124 - true_positives_3: 959.0000 - true_negatives_3: 957.0000 - val_loss: 0.3165 - val_accuracy: 0.8733 - val_true_positives_3: 214.0000 - val_true_negatives_3: 179.0000
# Epoch 7/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.2339 - accuracy: 0.9243 - true_positives_3: 977.0000 - true_negatives_3: 964.0000 - val_loss: 0.2581 - val_accuracy: 0.9067 - val_true_positives_3: 210.0000 - val_true_negatives_3: 198.0000
# Epoch 8/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.2124 - accuracy: 0.9286 - true_positives_3: 974.0000 - true_negatives_3: 976.0000 - val_loss: 0.2184 - val_accuracy: 0.9289 - val_true_positives_3: 201.0000 - val_true_negatives_3: 217.0000
# Epoch 9/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.1955 - accuracy: 0.9357 - true_positives_3: 987.0000 - true_negatives_3: 978.0000 - val_loss: 0.4569 - val_accuracy: 0.8200 - val_true_positives_3: 219.0000 - val_true_negatives_3: 150.0000
# Epoch 10/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1905 - accuracy: 0.9362 - true_positives_3: 987.0000 - true_negatives_3: 979.0000 - val_loss: 0.3472 - val_accuracy: 0.8600 - val_true_positives_3: 164.0000 - val_true_negatives_3: 223.0000
# Epoch 11/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1827 - accuracy: 0.9395 - true_positives_3: 987.0000 - true_negatives_3: 986.0000 - val_loss: 0.2037 - val_accuracy: 0.9178 - val_true_positives_3: 198.0000 - val_true_negatives_3: 215.0000
# Epoch 12/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1616 - accuracy: 0.9471 - true_positives_3: 1001.0000 - true_negatives_3: 988.0000 - val_loss: 0.2119 - val_accuracy: 0.9289 - val_true_positives_3: 211.0000 - val_true_negatives_3: 207.0000
# Epoch 13/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.1563 - accuracy: 0.9510 - true_positives_3: 1005.0000 - true_negatives_3: 992.0000 - val_loss: 0.1984 - val_accuracy: 0.9333 - val_true_positives_3: 201.0000 - val_true_negatives_3: 219.0000
# Epoch 14/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1473 - accuracy: 0.9476 - true_positives_3: 1004.0000 - true_negatives_3: 986.0000 - val_loss: 0.3801 - val_accuracy: 0.8689 - val_true_positives_3: 167.0000 - val_true_negatives_3: 224.0000
# Epoch 15/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1338 - accuracy: 0.9552 - true_positives_3: 1014.0000 - true_negatives_3: 992.0000 - val_loss: 0.2424 - val_accuracy: 0.9244 - val_true_positives_3: 196.0000 - val_true_negatives_3: 220.0000
# Epoch 16/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1284 - accuracy: 0.9590 - true_positives_3: 1014.0000 - true_negatives_3: 1000.0000 - val_loss: 0.1983 - val_accuracy: 0.9289 - val_true_positives_3: 203.0000 - val_true_negatives_3: 215.0000
# Epoch 17/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1219 - accuracy: 0.9586 - true_positives_3: 1010.0000 - true_negatives_3: 1003.0000 - val_loss: 0.2046 - val_accuracy: 0.9267 - val_true_positives_3: 203.0000 - val_true_negatives_3: 214.0000
# Epoch 18/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1167 - accuracy: 0.9576 - true_positives_3: 1014.0000 - true_negatives_3: 997.0000 - val_loss: 0.1985 - val_accuracy: 0.9311 - val_true_positives_3: 214.0000 - val_true_negatives_3: 205.0000
# Epoch 19/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1051 - accuracy: 0.9662 - true_positives_3: 1022.0000 - true_negatives_3: 1007.0000 - val_loss: 0.2253 - val_accuracy: 0.9244 - val_true_positives_3: 204.0000 - val_true_negatives_3: 212.0000
# Epoch 20/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0899 - accuracy: 0.9700 - true_positives_3: 1029.0000 - true_negatives_3: 1008.0000 - val_loss: 0.2570 - val_accuracy: 0.9200 - val_true_positives_3: 196.0000 - val_true_negatives_3: 218.0000

# %%
# test_loss, test_acc, true_pos, true_neg = model.evaluate(test_dataset)

# print(f"Test accuracy: {test_acc:.3f}",
#       f"\nTest loss: {test_loss:.3f}",
#       f"\nTrue positive: {true_pos:.3f}",
#       f"\nTest accuracy: {true_neg:.3f}")

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# kernel size = 5

# %%
inputs = keras.Input(shape=INPUT_SHAPE)
#-----------------------------------------------------------------
x = inputs
x = layers.Rescaling(1./255)(inputs)
#---------------------------------------------------------------------------------------
x = layers.Conv2D(filters=8, kernel_size=5, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=16, kernel_size=5, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=32, kernel_size=5, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=5, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=5, activation="relu")(x)

x = layers.Flatten()(x)
x = layers.Dense(8, activation="sigmoid")(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
               optimizer="rmsprop",
               metrics=["accuracy",tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives()])


history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = EPOCHS)
# Out:
# Epoch 1/20
# 132/132 [==============================] - 8s 43ms/step - loss: 0.5632 - accuracy: 0.7119 - true_positives_4: 630.0000 - true_negatives_4: 865.0000 - val_loss: 0.4400 - val_accuracy: 0.8133 - val_true_positives_4: 151.0000 - val_true_negatives_4: 215.0000
# Epoch 2/20
# 132/132 [==============================] - 6s 40ms/step - loss: 0.3764 - accuracy: 0.8543 - true_positives_4: 895.0000 - true_negatives_4: 899.0000 - val_loss: 0.3573 - val_accuracy: 0.8667 - val_true_positives_4: 205.0000 - val_true_negatives_4: 185.0000
# Epoch 3/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.3180 - accuracy: 0.8805 - true_positives_4: 926.0000 - true_negatives_4: 923.0000 - val_loss: 0.2809 - val_accuracy: 0.9022 - val_true_positives_4: 196.0000 - val_true_negatives_4: 210.0000
# Epoch 4/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.2716 - accuracy: 0.9086 - true_positives_4: 956.0000 - true_negatives_4: 952.0000 - val_loss: 0.2708 - val_accuracy: 0.9067 - val_true_positives_4: 207.0000 - val_true_negatives_4: 201.0000
# Epoch 5/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.2373 - accuracy: 0.9181 - true_positives_4: 972.0000 - true_negatives_4: 956.0000 - val_loss: 0.2818 - val_accuracy: 0.8822 - val_true_positives_4: 214.0000 - val_true_negatives_4: 183.0000
# Epoch 6/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.2084 - accuracy: 0.9271 - true_positives_4: 967.0000 - true_negatives_4: 980.0000 - val_loss: 0.2960 - val_accuracy: 0.8978 - val_true_positives_4: 215.0000 - val_true_negatives_4: 189.0000
# Epoch 7/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.1817 - accuracy: 0.9400 - true_positives_4: 986.0000 - true_negatives_4: 988.0000 - val_loss: 0.2872 - val_accuracy: 0.8889 - val_true_positives_4: 207.0000 - val_true_negatives_4: 193.0000
# Epoch 8/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.1759 - accuracy: 0.9410 - true_positives_4: 997.0000 - true_negatives_4: 979.0000 - val_loss: 0.4095 - val_accuracy: 0.8444 - val_true_positives_4: 221.0000 - val_true_negatives_4: 159.0000
# Epoch 9/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1687 - accuracy: 0.9448 - true_positives_4: 1004.0000 - true_negatives_4: 980.0000 - val_loss: 0.2828 - val_accuracy: 0.9067 - val_true_positives_4: 189.0000 - val_true_negatives_4: 219.0000
# Epoch 10/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.1451 - accuracy: 0.9538 - true_positives_4: 1002.0000 - true_negatives_4: 1001.0000 - val_loss: 0.2538 - val_accuracy: 0.9067 - val_true_positives_4: 213.0000 - val_true_negatives_4: 195.0000
# Epoch 11/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.1647 - accuracy: 0.9486 - true_positives_4: 1004.0000 - true_negatives_4: 988.0000 - val_loss: 0.2358 - val_accuracy: 0.9156 - val_true_positives_4: 203.0000 - val_true_negatives_4: 209.0000
# Epoch 12/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.1334 - accuracy: 0.9595 - true_positives_4: 1009.0000 - true_negatives_4: 1006.0000 - val_loss: 0.2307 - val_accuracy: 0.9178 - val_true_positives_4: 209.0000 - val_true_negatives_4: 204.0000
# Epoch 13/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.1141 - accuracy: 0.9662 - true_positives_4: 1016.0000 - true_negatives_4: 1013.0000 - val_loss: 0.2569 - val_accuracy: 0.9022 - val_true_positives_4: 207.0000 - val_true_negatives_4: 199.0000
# Epoch 14/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1095 - accuracy: 0.9667 - true_positives_4: 1018.0000 - true_negatives_4: 1012.0000 - val_loss: 0.3059 - val_accuracy: 0.9067 - val_true_positives_4: 187.0000 - val_true_negatives_4: 221.0000
# Epoch 15/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.1073 - accuracy: 0.9662 - true_positives_4: 1015.0000 - true_negatives_4: 1014.0000 - val_loss: 0.2232 - val_accuracy: 0.9311 - val_true_positives_4: 210.0000 - val_true_negatives_4: 209.0000
# Epoch 16/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0948 - accuracy: 0.9700 - true_positives_4: 1024.0000 - true_negatives_4: 1013.0000 - val_loss: 0.2485 - val_accuracy: 0.9178 - val_true_positives_4: 200.0000 - val_true_negatives_4: 213.0000
# Epoch 17/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0958 - accuracy: 0.9714 - true_positives_4: 1020.0000 - true_negatives_4: 1020.0000 - val_loss: 0.2714 - val_accuracy: 0.9156 - val_true_positives_4: 199.0000 - val_true_negatives_4: 213.0000
# Epoch 18/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.0724 - accuracy: 0.9819 - true_positives_4: 1034.0000 - true_negatives_4: 1028.0000 - val_loss: 0.2870 - val_accuracy: 0.9222 - val_true_positives_4: 199.0000 - val_true_negatives_4: 216.0000
# Epoch 19/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.0821 - accuracy: 0.9771 - true_positives_4: 1029.0000 - true_negatives_4: 1023.0000 - val_loss: 0.2885 - val_accuracy: 0.9111 - val_true_positives_4: 204.0000 - val_true_negatives_4: 206.0000
# Epoch 20/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0765 - accuracy: 0.9805 - true_positives_4: 1032.0000 - true_negatives_4: 1027.0000 - val_loss: 0.2731 - val_accuracy: 0.9200 - val_true_positives_4: 193.0000 - val_true_negatives_4: 221.0000

# %%
# test_loss, test_acc, true_pos, true_neg = model.evaluate(test_dataset)

# print(f"Test accuracy: {test_acc:.3f}",
#       f"\nTest loss: {test_loss:.3f}",
#       f"\nTrue positive: {true_pos:.3f}",
#       f"\nTest accuracy: {true_neg:.3f}")

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()
